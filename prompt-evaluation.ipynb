# %% [markdown]
# Generating test datasets

# %%
from anthropic import Anthropic
from dotenv import load_dotenv
load_dotenv()

import json

# %%
model = "claude-sonnet-4-0"
client = Anthropic()

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    if stop_sequences:
        params["stop_sequences"] = stop_sequences
    
    response = client.messages.create(**params)
    return response.content[0].text

# %%
# Generating Test Data with Code
def generate_dataset():
    prompt = """
Generate an evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects, each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
  {
    "task": "Description of task",
  },
  ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a single regex
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset
dataset = generate_dataset()
print(dataset)
# Out:
# [{'task': "Write a Python function that validates whether an AWS S3 bucket name follows AWS naming conventions (3-63 characters, lowercase letters/numbers/hyphens only, no consecutive hyphens, doesn't start/end with hyphen)"}, {'task': "Create a JSON object representing an AWS IAM policy that grants read-only access to a specific S3 bucket named 'my-app-logs' and all objects within it"}, {'task': 'Write a regex pattern that matches valid AWS EC2 instance IDs (format: i- followed by 8 or 17 hexadecimal characters)'}]

# %%
# Save dataset to a JSON file
with open(r'dataset/test-case-dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
# This function takes a test case and merges it with our prompt template:

def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Implementing a Model Grader

def grade_by_model(test_case, output):
    # Create evaluation prompt
    eval_prompt = """
    You are an expert code reviewer. Evaluate this AI-generated solution.
    
    Task: {task}
    Solution: {solution}
    
    Provide your evaluation as a structured JSON object with:
    - "strengths": An array of 1-3 key strengths
    - "weaknesses": An array of 1-3 key areas for improvement  
    - "reasoning": A concise explanation of your assessment
    - "score": A number between 1-10
    """
    
    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# This function orchestrates running a single test case and grading the result:

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    # Grade the output
    reasoning = model_grade["reasoning"]
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

# %%
# This function coordinates the entire evaluation process:

from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open(r"dataset/test-case-dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
# Examining the Results
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "Here's a Python function that creates a properly formatted S3 URI with bucket name validation:\n\n```python\nimport re\n\ndef create_s3_uri(bucket_name, object_key):\n    \"\"\"\n    Creates a properly formatted S3 URI from bucket name and object key.\n    \n    Args:\n        bucket_name (str): The S3 bucket name\n        object_key (str): The S3 object key\n    \n    Returns:\n        str: Properly formatted S3 URI (s3://bucket-name/object-key)\n    \n    Raises:\n        ValueError: If bucket_name contains invalid characters\n        TypeError: If inputs are not strings\n    \"\"\"\n    # Type validation\n    if not isinstance(bucket_name, str):\n        raise TypeError(\"bucket_name must be a string\")\n    if not isinstance(object_key, str):\n        raise TypeError(\"object_key must be a string\")\n    \n    # Validate bucket name is not empty\n    if not bucket_name:\n        raise ValueError(\"bucket_name cannot be empty\")\n    \n    # Validate bucket name contains only lowercase letters, numbers, and hyphens\n    if not re.match(r'^[a-z0-9-]+$', bucket_name):\n        raise ValueError(\"bucket_name must contain only lowercase letters, numbers, and hyphens\")\n    \n    # Remove leading slash from object_key if present to avoid double slashes\n    object_key = object_key.lstrip('/')\n    \n    # Create and return the S3 URI\n    return f\"s3://{bucket_name}/{object_key}\"\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    # Test valid cases\n    try:\n        print(create_s3_uri(\"my-bucket\", \"folder/file.txt\"))\n        # Output: s3://my-bucket/folder/file.txt\n        \n        print(create_s3_uri(\"bucket123\", \"data/2023/report.csv\"))\n        # Output: s3://bucket123/data/2023/report.csv\n        \n        print(create_s3_uri(\"test-bucket-1\", \"/leading-slash-removed.json\"))\n        # Output: s3://test-bucket-1/leading-slash-removed.json\n        \n    except (ValueError, TypeError) as e:\n        print(f\"Error: {e}\")\n    \n    # Test invalid cases\n    invalid_test_cases = [\n        (\"My-Bucket\", \"file.txt\"),  # uppercase letters\n        (\"my_bucket\", \"file.txt\"),  # underscore\n        (\"my.bucket\", \"file.txt\"),  # dot\n        (\"\", \"file.txt\"),           # empty bucket name\n        (123, \"file.txt\"),          # non-string bucket name\n        (\"my-bucket\", 456),         # non-string object key\n    ]\n    \n    print(\"\\nTesting invalid cases:\")\n    for bucket, key in invalid_test_cases:\n        try:\n            result = create_s3_uri(bucket, key)\n            print(f\"Unexpected success: {result}\")\n        except (ValueError, TypeError) as e:\n            print(f\"Expected error for ({bucket}, {key}): {e}\")\n```\n\nThis function includes:\n\n1. **Validation**: \n   - Checks that both parameters are strings\n   - Validates the bucket name is not empty\n   - Uses regex to ensure bucket name contains only lowercase letters (a-z), numbers (0-9), and hyphens (-)\n\n2. **Error Handling**:\n   - Raises `TypeError` for non-string inputs\n   - Raises `ValueError` for invalid bucket names\n\n3. **URI Formatting**:\n   - Creates the proper S3 URI format: `s3://bucket-name/object-key`\n   - Removes leading slashes from object keys to prevent double slashes\n\n4. **Edge Case Handling**:\n   - Handles object keys that might start with a forward slash\n\nThe function follows AWS S3 bucket naming conventions for the validation (though it's a simplified version - full S3 bucket naming rules are more complex, but this covers the basic requirement specified in the task).",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and object key as parameters and returns a properly formatted S3 URI (s3://bucket-name/object-key). The function should validate that the bucket name contains only lowercase letters, numbers, and hyphens."
#     },
#     "score": 10
#   },
#   {
#     "output": "Here's a JSON object representing an AWS IAM policy that provides read-only access to the 'my-app-logs' S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-app-logs\"\n    },\n    {\n      \"Sid\": \"GetObjectAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-app-logs/*\"\n    },\n    {\n      \"Sid\": \"DenyWriteOperations\",\n      \"Effect\": \"Deny\",\n      \"Action\": [\n        \"s3:PutObject\",\n        \"s3:PutObjectAcl\",\n        \"s3:DeleteObject\",\n        \"s3:DeleteObjectVersion\",\n        \"s3:PutBucketAcl\",\n        \"s3:PutBucketPolicy\",\n        \"s3:DeleteBucket\",\n        \"s3:PutBucketVersioning\",\n        \"s3:PutLifecycleConfiguration\",\n        \"s3:PutBucketCORS\",\n        \"s3:PutBucketNotification\",\n        \"s3:PutBucketLogging\",\n        \"s3:PutBucketWebsite\",\n        \"s3:RestoreObject\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-app-logs\",\n        \"arn:aws:s3:::my-app-logs/*\"\n      ]\n    }\n  ]\n}\n```\n\n**Explanation of the policy components:**\n\n1. **ListBucketAccess Statement**: \n   - Allows listing the contents of the bucket (`s3:ListBucket`)\n   - Allows getting the bucket's location (`s3:GetBucketLocation`)\n   - Applies to the bucket itself (`arn:aws:s3:::my-app-logs`)\n\n2. **GetObjectAccess Statement**:\n   - Allows reading/downloading objects (`s3:GetObject`)\n   - Allows reading specific versions of objects (`s3:GetObjectVersion`)\n   - Applies to all objects within the bucket (`arn:aws:s3:::my-app-logs/*`)\n\n3. **DenyWriteOperations Statement**:\n   - Explicitly denies all common write operations\n   - Includes object-level operations (put, delete) and bucket-level operations\n   - Applies to both the bucket and its contents\n   - The explicit deny ensures that even if other policies grant write access, it will be overridden\n\nThis policy follows the principle of least privilege by only granting the minimum permissions necessary for read-only access while explicitly blocking write operations.",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows read-only access to a specific S3 bucket named 'my-app-logs'. The policy should include the necessary statements to list bucket contents and get objects, but deny any write operations."
#     },
#     "score": 10
#   },
#   {
#     "output": "Here's a regex pattern that validates AWS Lambda function names according to the specified requirements:\n\n```regex\n^[a-zA-Z0-9_]([a-zA-Z0-9_-]{0,62}[a-zA-Z0-9_])?$\n```\n\n## Explanation:\n\n- `^` - Start of string\n- `[a-zA-Z0-9_]` - First character must be a letter, number, or underscore (cannot be hyphen)\n- `([a-zA-Z0-9_-]{0,62}[a-zA-Z0-9_])?` - Optional group for names longer than 1 character:\n  - `[a-zA-Z0-9_-]{0,62}` - Middle characters (0-62 of them) can be letters, numbers, hyphens, or underscores\n  - `[a-zA-Z0-9_]` - Last character must be a letter, number, or underscore (cannot be hyphen)\n- `$` - End of string\n\n## How it works:\n\n1. **Length constraint (1-64 characters)**: The pattern allows 1 character minimum (first character) and up to 64 characters maximum (1 + 62 + 1)\n2. **Valid characters**: Only letters (a-z, A-Z), numbers (0-9), hyphens (-), and underscores (_)\n3. **Cannot start with hyphen**: First character class excludes hyphen\n4. **Cannot end with hyphen**: Last character class excludes hyphen\n5. **Single character names**: Handled by making the middle/end group optional with `?`\n\n## Test examples:\n\n\u2705 **Valid names:**\n- `myFunction`\n- `my-function`\n- `my_function_2`\n- `MyFunction123`\n- `a`\n- `function-name-with-underscores_and_hyphens`\n\n\u274c **Invalid names:**\n- `-myFunction` (starts with hyphen)\n- `myFunction-` (ends with hyphen)\n- `my function` (contains space)\n- `my@function` (contains invalid character)\n- `` (empty string)\n- `a-very-long-function-name-that-exceeds-the-maximum-length-limit-of-64-characters` (too long)",
#     "test_case": {
#       "task": "Write a regex pattern that validates AWS Lambda function names according to AWS naming requirements: must be 1-64 characters long, contain only letters, numbers, hyphens, and underscores, and cannot start or end with a hyphen."
#     },
#     "score": 10
#   }
# ]

# %% [markdown]
# Each result contains three key pieces of information:
#
# - output: The complete response from Claude
# - test_case: The original test case that was processed
# - score: The evaluation score (currently hardcoded)
